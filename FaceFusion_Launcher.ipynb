# %% [markdown]
# # FaceFusion Launcher
#
# Run the cell below to unpack the FaceFusion application.

# %%
import base64import osprint('Initializing...')# Encoded data chunksdata_chunks = [    '...',    '...',    '...',    'OiBodHRwczovL2dpdGh1Yi5jb20vZmFjZWZ1c2lvbi9mYWNlZnVzaW9uIgogICAgICBdLAogICAgICAibWV0YWRhdGEiOiB7CiAgICAgICAgImlkIjogInRyb3VibGVzaG9vdGluZyIKICAgICAgfQogICAgfQogIF0KfQo=',]full_data = ''.join(data_chunks)output_file = 'FaceFusion_App.ipynb'with open(output_file, 'wb') as f:    f.write(base64.b64decode(full_data))print(f'✅ Successfully decoded!')print(f'👉 Please double-click "{output_file}" in the file browser on the left to open the app.')
